# %% [markdown]
# <a href="https://colab.research.google.com/github/stephenfarrell10/low-code-book-projects/blob/main/chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD"

# %%
heart_df = pd.read_csv(url, index_col=0)

# %%
heart_df.head()
# Out:
#      LocationAbbr LocationDesc GeographicLevel DataSource  \
# Year
# 2019           MO   Ray County          County       NVSS
# 2019           MT      Montana           State       NVSS
# 2019           MT      Montana           State       NVSS
# 2019           MT      Montana           State       NVSS
# 2019           MT      Montana           State       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       531.9
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 2019  Cardiovascular Diseases  Heart Disease Mortality       234.0
# 2019  Cardiovascular Diseases  Heart Disease Mortality       285.3
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
#
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59094 entries, 2019 to 2019
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                59094 non-null  object
#  1   LocationDesc                59094 non-null  object
#  2   GeographicLevel             59094 non-null  object
#  3   DataSource                  59094 non-null  object
#  4   Class                       59094 non-null  object
#  5   Topic                       59094 non-null  object
#  6   Data_Value                  33087 non-null  float64
#  7   Data_Value_Unit             59094 non-null  object
#  8   Data_Value_Type             59094 non-null  object
#  9   Data_Value_Footnote_Symbol  26007 non-null  object
#  10  Data_Value_Footnote         26007 non-null  object
#  11  StratificationCategory1     59094 non-null  object
#  12  Stratification1             59094 non-null  object
# ...

# %%
heart_df.isna().sum()
# Out:
# LocationAbbr                      0
# LocationDesc                      0
# GeographicLevel                   0
# DataSource                        0
# Class                             0
# Topic                             0
# Data_Value                    26007
# Data_Value_Unit                   0
# Data_Value_Type                   0
# Data_Value_Footnote_Symbol    33087
# Data_Value_Footnote           33087
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2           0
# Stratification2                   0
# TopicID                           0
# LocationID                        0
# Y_lat                            18
# X_lon                            18
# dtype: int64

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Black', 'Hispanic', 'Asian and Pacific Islander', 'White',
#        'Overall', 'American Indian and Alaskan Native'], dtype=object)

# %%
sns.displot(heart_df['Data_Value'])
